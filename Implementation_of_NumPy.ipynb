# %%
import numpy as np

# %%
x = np.array([1,2,3,4,5])
print(x)
print(type(x))

y = np.array([[1,2,3,4,5]])
print(y)
print(type(y))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
# [[1 2 3 4 5]]
# <class 'numpy.ndarray'>

# %%
print(np.array([[1], [2], [3], [4], [5]]))
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
import numpy as np
from skimage import io
photo = io.imread('taj_mahal.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (431, 612, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
#FLIP THE IMAGE UPSIDE DOWN

plt.imshow(photo[::-1])

# %%
# MIRROR IMAGE

plt.imshow(photo[:,::-1])

# %%
# TAKE A SNAP OUT OF THE OG PHOTO
plt.imshow(photo[50:265, 250: 355])

# %%
plt.imshow(photo[::5, ::5])

# %%
print(np.min(photo))
print(np.max(photo))
# Out:
# 0
# 255

# %%
photo_masked = np.where(photo > 180, 255, 0)
plt.imshow(photo_masked)

# %%
###Old

# %%
plt.imshow(photo[:,:,0].T)

# %%
import time
for i in range(100):
  if i % 100 == 0:
    print(i)
  time.sleep(0.1)
# Out:
# 0
